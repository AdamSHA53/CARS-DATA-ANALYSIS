# %%
from google.colab import files

# Upload the dataset from your local device
uploaded = files.upload()

import pandas as pd

# Read the uploaded file into a DataFrame
import io
car_sales_data = pd.read_csv(io.BytesIO(uploaded['Cars_dataset.csv']))
# Out:
#      <input type="file" id="files-5de15ccd-bf01-40cb-8a1a-fa9f6dce9c7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5de15ccd-bf01-40cb-8a1a-fa9f6dce9c7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd



# Display basic information about the dataset
print("Information about the dataset:")
print(car_sales_data.info())

# Display description of the dataset
print("\nDescription of the dataset:")
print(car_sales_data.describe())
# Out:
# Information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          156 non-null    int64
#  1   Model               156 non-null    object
#  2   Maker               156 non-null    object
#  3   Type                156 non-null    object
#  4   Seats               156 non-null    int64
#  5   Displacement        155 non-null    float64
#  6   Length              156 non-null    int64
#  7   Width               156 non-null    int64
#  8   Height              156 non-null    int64
#  9   Wheelbase           156 non-null    int64
#  10  No_of_Cylinders     155 non-null    float64
#  11  Fuel                156 non-null    object
#  12  Engine Type         156 non-null    object
#  13  Transmission        155 non-null    object
#  14  Front Brake         156 non-null    object
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings

# Ignore warnings
warnings.filterwarnings("ignore")

# %%
# Importing necessary libraries
import pandas as pd

# Read the uploaded file into a DataFrame
import io
car_sales_data = pd.read_csv(io.BytesIO(uploaded['Cars_dataset.csv']))

# Display the data in tabular format
car_sales_data.head()
# Out:
#    Unnamed: 0      Model       Maker           Type  Seats  Displacement  \
# 0          24       GT-R      Nissan     Sports Car      2        3799.0
# 1          40  Scorpio-N    Mahindra            SUV      6        2000.0
# 2           2     Virtus  Volkswagen          Sedan      5        1498.0
# 3           9      Amaze       Honda  Compact Sedan      5        1199.0
# 4           8      Amaze       Honda  Compact Sedan      5        1199.0
#
#    Length  Width  Height  Wheelbase  ...  Rear Brake Drive Turning Radius  \
# 0    4710   1895    1370       2780  ...        Disc  4 WD           5.57
# 1    4662   1917    1857       2750  ...        Disc   2WD            NaN
# 2    4561   1752    1507       2651  ...        Drum   2WD           5.05
# 3    3995   1695    1501       2470  ...        Drum   2WD           4.70
# 4    3995   1695    1501       2470  ...        Drum   2WD           4.70
#
#   Fuel Tank Capacity Boot Space Fuel Efficiency Emission Type   Tyre Size  \
# ...

# %%
Cars_df.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Maker', 'Type', 'Seats', 'Displacement',
#        'Length', 'Width', 'Height', 'Wheelbase', 'No_of_Cylinders', 'Fuel',
#        'Engine Type', 'Transmission', 'Front Brake', 'Rear Brake', 'Drive',
#        'Turning Radius', 'Fuel Tank Capacity', 'Boot Space', 'Fuel Efficiency',
#        'Emission Type', 'Tyre Size', 'Variants', 'NCAP Rating'],
#       dtype='object')

# %%
# Select a project name
project='car India dataset'

# %%
selected_columns = [
    'Model',
    'Maker',
    'Type',
    'Seats',
    'Displacement',
    'Length',
    'Width',
    'Height',
    'Wheelbase',
    'No_of_Cylinders',
    'Fuel',
    'Engine Type',
    'Transmission',
    'Front Brake',
    'Rear Brake',
    'Drive',
    'Turning Radius',
    'Fuel Tank Capacity',
    'Boot Space',
    'Fuel Efficiency',
]

# %%
len(selected_columns)
# Out:
# 20

# %%
Car_india_df = Cars_df[selected_columns].copy()

# %%
Car_india_df
# Out:
#              Model       Maker           Type  Seats  Displacement  Length  \
# 0             GT-R      Nissan     Sports Car      2        3799.0    4710
# 1        Scorpio-N    Mahindra            SUV      6        2000.0    4662
# 2           Virtus  Volkswagen          Sedan      5        1498.0    4561
# 3            Amaze       Honda  Compact Sedan      5        1199.0    3995
# 4            Amaze       Honda  Compact Sedan      5        1199.0    3995
# ..             ...         ...            ...    ...           ...     ...
# 151        Magnite      Nissan    Compact SUV      5         999.0    3994
# 152        Magnite      Nissan    Compact SUV      5         999.0    3994
# 153        Magnite      Nissan    Compact SUV      5         999.0    3994
# 154         Virtus  Volkswagen          Sedan      5         999.0    4561
# 155  Kona Electric     Hyundai            SUV      5           NaN    4180
#
#      Width  Height  Wheelbase  No_of_Cylinders      Fuel  \
# ...

# %%
Car_india_df.shape
# Out:
# (156, 20)

# %%
Car_india_df.sample(10)
# Out:
#           Model     Maker         Type  Seats  Displacement  Length  Width  \
# 46      Marazzo  Mahindra          MPV      7        1497.0    4585   1866
# 150     XUV 300  Mahindra  Compact SUV      5        1197.0    3995   1821
# 140      Triber   Renault          MUV      7         999.0    3991   1739
# 20    Scorpio-N  Mahindra          SUV      6        2000.0    4662   1917
# 67       Safari      Tata          SUV      7        1956.0    4661   1894
# 134       Kiger   Renault  Compact SUV      5         999.0    3991   1750
# 53      XUV 300  Mahindra  Compact SUV      5        1497.0    3995   1821
# 50         Jazz     Honda    Hatchback      5        1199.0    3989   1694
# 65   City e-HEV     Honda        Sedan      5        1498.0    4549   1748
# 136          C3   Citroen    Hatchback      5        1198.0    3981   1733
#
#      Height  Wheelbase  No_of_Cylinders           Fuel  \
# 46     1774       2760              4.0         Diesel
# ...

# %% [markdown]
# exploratory analysis and visualization

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# Maker

# %%
Car_maker = Car_india_df.Maker.value_counts()

# %%
Car_maker
# Out:
# Hyundai       42
# Mahindra      32
# Kia           24
# Honda         13
# Toyota        12
# Renault        9
# Volkswagen     8
# Nissan         7
# Tata           6
# Citroen        3
# Name: Maker, dtype: int64

# %%
Car_maker.nunique()
# Out:
# 10

# %% [markdown]
# Bar grapph

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
plt.title("Different kinds of car makers in India")
plt.xlabel('Car manufacturer')
sns.barplot(x=Car_maker.index, y=Car_maker);

# %% [markdown]
# TYPE

# %%
Car_type = Car_india_df.Type.value_counts()

# %%
Car_type
# Out:
# SUV              71
# Compact SUV      25
# Hatchback        20
# Sedan            13
# MUV              10
# Compact Sedan     8
# MPV               4
# Mid Size SUV      4
# Sports Car        1
# Name: Type, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
plt.title("Various car types in India")
plt.xlabel('Car type');
sns.barplot(x=Car_type.index, y=Car_type);

# %% [markdown]
# Seats

# %%
Seats_number = Car_india_df.Seats

# %%
Seats_number
# Out:
# 0      2
# 1      6
# 2      5
# 3      5
# 4      5
#       ..
# 151    5
# 152    5
# 153    5
# 154    5
# 155    5
# Name: Seats, Length: 156, dtype: int64

# %%
import numpy as np

# %%
plt.figure(figsize=(12, 6))
plt.title('Number of seats')
plt.xlabel('Seats')
plt.ylabel('Number of cars')

plt.hist(Car_india_df.Seats, bins=np.arange(2,10,1), color='blue');

# %% [markdown]
# Fuel

# %%
Fuel_counts = Car_india_df.Fuel.value_counts()

# %%
Fuel_counts
# Out:
# Petrol           93
# Diesel           59
# Petrol + CNG      2
# Petrol Hybrid     1
# Electric          1
# Name: Fuel, dtype: int64

# %%
Fuel_counts.index
# Out:
# Index(['Petrol', 'Diesel', 'Petrol + CNG', 'Petrol Hybrid', 'Electric'], dtype='object')

# %%
plt.figure(figsize=(12,10))
plt.title('Types of fuel consumed by cars in India')
plt.pie(Fuel_counts, labels=Fuel_counts.index, autopct='%1.1f%%', startangle=180);

# %%
Car_india_df
# Out:
#              Model       Maker           Type  Seats  Displacement  Length  \
# 0             GT-R      Nissan     Sports Car      2        3799.0    4710
# 1        Scorpio-N    Mahindra            SUV      6        2000.0    4662
# 2           Virtus  Volkswagen          Sedan      5        1498.0    4561
# 3            Amaze       Honda  Compact Sedan      5        1199.0    3995
# 4            Amaze       Honda  Compact Sedan      5        1199.0    3995
# ..             ...         ...            ...    ...           ...     ...
# 151        Magnite      Nissan    Compact SUV      5         999.0    3994
# 152        Magnite      Nissan    Compact SUV      5         999.0    3994
# 153        Magnite      Nissan    Compact SUV      5         999.0    3994
# 154         Virtus  Volkswagen          Sedan      5         999.0    4561
# 155  Kona Electric     Hyundai            SUV      5           NaN    4180
#
#      Width  Height  Wheelbase  No_of_Cylinders      Fuel  \
# ...

# %%
Car_model = Car_india_df.Model

# %%
Car_model
# Out:
# 0               GT-R
# 1          Scorpio-N
# 2             Virtus
# 3              Amaze
# 4              Amaze
#            ...
# 151          Magnite
# 152          Magnite
# 153          Magnite
# 154           Virtus
# 155    Kona Electric
# Name: Model, Length: 156, dtype: object

# %%
Car_model.unique()
# Out:
# array(['GT-R', 'Scorpio-N', 'Virtus', 'Amaze', 'Tiguan',
#        'Scorpio Classic', 'WR-V', 'Jazz', 'Kicks', 'C5 Aircross',
#        'City 5th Gen', 'Grand i10 Nios', 'Aura', 'Fortuner', 'Sonet',
#        'Safari', 'Seltos', 'XUV 700', 'Thar LX', 'Thar AX OPT', 'Marazzo',
#        'XUV 300', 'Urban Cruiser', 'Fortuner Legender', 'City 4th Gen',
#        'City e-HEV', 'Creta', 'i20', 'Alcazar', 'Glanza', 'Verna',
#        'i20 N-Line', 'Venue', 'Venue N-Line', 'Tucson', 'Carens',
#        'Harrier', 'Carnival', 'Kiger', 'C3', 'Kwid', 'Triber', 'Taigun',
#        'Magnite', 'Kona Electric'], dtype=object)

# %%
len(Car_model.unique())
# Out:
# 45

# %%
plt.figure(figsize=(12,12))
sns.countplot(y=Car_india_df.Model)
plt.xticks(rotation=90);
plt.title("Different Car Models in India")
plt.ylabel(None);

# %% [markdown]
# Transmission

# %%
Car_india_df.Transmission
# Out:
# 0      6-Speed DCT
# 1             6 MT
# 2      7-Speed DSG
# 3              CVT
# 4             5 MT
#           ...
# 151           5 MT
# 152            CVT
# 153           5 MT
# 154     6-Speed MT
# 155            NaN
# Name: Transmission, Length: 156, dtype: object

# %%
Car_india_df.Transmission.value_counts()
# Out:
# 6 MT                   45
# 6 AT                   30
# 5 MT                   25
# 7 DCT                   9
# AMT                     6
# CVT                     6
# 8 AT                    6
# IVT                     4
# iMT                     3
# 6-Speed MT              3
# 6  iMT                  2
# 6 MT with iMT           2
# 6 TC Automatic          2
# 7-Speed DSG             2
# 6-Speed AT              2
# 6 iMT                   1
# 7-Speed CVT             1
# 7-Speed DSG 4MOTION     1
# 4 AT                    1
# Single                  1
# MT                      1
# DCT                     1
# 6-Speed DCT             1
# Name: Transmission, dtype: int64

# %%
Car_india_df.Transmission.count()
# Out:
# 155

# %%
Transmission_pct = Car_india_df.Transmission.value_counts()*100 / Car_india_df.Transmission.count()
Transmission_pct
# Out:
# 6 MT                   29.032258
# 6 AT                   19.354839
# 5 MT                   16.129032
# 7 DCT                   5.806452
# AMT                     3.870968
# CVT                     3.870968
# 8 AT                    3.870968
# IVT                     2.580645
# iMT                     1.935484
# 6-Speed MT              1.935484
# 6  iMT                  1.290323
# 6 MT with iMT           1.290323
# 6 TC Automatic          1.290323
# 7-Speed DSG             1.290323
# 6-Speed AT              1.290323
# 6 iMT                   0.645161
# 7-Speed CVT             0.645161
# 7-Speed DSG 4MOTION     0.645161
# 4 AT                    0.645161
# Single                  0.645161
# MT                      0.645161
# DCT                     0.645161
# 6-Speed DCT             0.645161
# Name: Transmission, dtype: float64

# %%
Transmission_pct.index
# Out:
# Index(['6 MT', '6 AT', '5 MT', '7 DCT', 'AMT', 'CVT', '8 AT', 'IVT', 'iMT',
#        '6-Speed MT', '6  iMT', '6 MT with iMT', '6 TC Automatic',
#        '7-Speed DSG', '6-Speed AT', '6 iMT', '7-Speed CVT',
#        '7-Speed DSG 4MOTION', '4 AT', 'Single', 'MT', 'DCT', '6-Speed DCT'],
#       dtype='object')

# %%
plt.figure(figsize=(12,10))
Transmission_pct = Car_india_df.Transmission.value_counts()*100 / Car_india_df.Transmission.count()

sns.barplot(x=Transmission_pct, y=Transmission_pct.index)

plt.title("Various Transmission systems used in India")
plt.ylabel(None);
plt.xlabel('Percentage');
